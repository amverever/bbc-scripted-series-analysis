# %%
import pandas as pd

# %%
drama = pd.read_csv("drama.csv", index_col = "id")
drama
# Out:
#       genre             name classification  season  episode   status  \
# id
# 1     Drama       Blake's 7‎            NaN       4       52     done
# 2     Drama       Doctor Who        Classic      26      694     done
# 3     Drama       Doctor Who        Revival      13      153  renewed
# 4     Drama       EastEnders            NaN      32     6756  renewed
# 5     Drama       Holby City            NaN      23     1102     done
# ...     ...              ...            ...     ...      ...      ...
# 1102  Drama  Out of Her Mind            NaN       1        6     done
# 1103  Drama      The Outlaws            NaN       2       12     done
# 1104  Drama     Rock & Chips            NaN       1        3     done
# 1105  Drama     Trigonometry            NaN       1        8     done
# 1106  Drama     Tutti Frutti            NaN       1        6     done
#
#      premiere_date   last_date
# id
# 1       1978-01-02  1981-12-21
# 2       1963-11-23  1989-12-06
# ...

# %%
drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1106 entries, 1 to 1106
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   genre           1106 non-null   object
#  1   name            1106 non-null   object
#  2   classification  181 non-null    object
#  3   season          1106 non-null   int64
#  4   episode         1106 non-null   int64
#  5   status          1106 non-null   object
#  6   premiere_date   1106 non-null   datetime64[ns]
#  7   last_date       1071 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 77.8+ KB

# %%
drama = drama.astype({"premiere_date": "datetime64", "last_date": "datetime64"})
